# %% [markdown]
# # Red Shift Evaluation
#
# Load the saved GPU policy checkpoint, evaluate baseline vs trained on the same seed tasks, and regenerate plots.

# %%
import os, sys, json
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))
sys.path.insert(0, str(ROOT / "scripts"))
os.chdir(ROOT)

# %%
# !PYTHONPATH=src:scripts python scripts/evaluate_redshift_policy.py --checkpoint training_results/curriculum_policy/policy.pt --curriculum-buffer curriculum_results/buffer.json --feature-mode spec --out-dir eval_results/curriculum_policy --plot-prefix curriculum_policy

# %%
from pathlib import Path
import json
summary = json.loads(Path("eval_results/curriculum_policy/summary.json").read_text())
print(json.dumps({"baseline": summary["baseline"]["mean"], "trained": summary["trained"]["mean"], "eval_size": summary["eval_size"]}, indent=2))

# %%
from IPython.display import Image, display
display(Image("docs/plots/curriculum_policy_baseline_vs_trained.png"))
display(Image("docs/plots/curriculum_policy_training_curve.png"))

# %% [markdown]
# ## Autocurriculum Artifacts

# %%
# !PYTHONPATH=src python scripts/run_autocurriculum.py --iterations 200 --write-yaml
from IPython.display import Image, display
display(Image("docs/plots/autocurriculum_diversity.png"))
display(Image("docs/plots/autocurriculum_solve_rate_hist.png"))
